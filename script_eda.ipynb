# %% [markdown]
# # __Exploratory data analysis__
#
# Ref:
# - [Exploratory Data Analysis for Natural Language Processing: A Complete Guide to Python Tools](https://neptune.ai/blog/exploratory-data-analysis-natural-language-processing-tools)
# - [A Beginner’s Guide to Exploratory Data Analysis (EDA) on Text Data (Amazon Case Study)](https://www.analyticsvidhya.com/blog/2020/04/beginners-guide-exploratory-data-analysis-text-data/)
# - [NLP Part 3 | Exploratory Data Analysis of Text Data](https://towardsdatascience.com/nlp-part-3-exploratory-data-analysis-of-text-data-1caa8ab3f79d)
#
# Log:
# - 10/31/23: started

# %% [markdown]
# ## ___Setup___

# %%
import pandas as pd
from pathlib import Path
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer

# %%
work_dir  = Path.home() / "projects/plantbert"
data_dir  = work_dir / "data"
model_dir = work_dir / "models"
vocab_dir = work_dir / "vocab"

corpus_file = data_dir / "corpus_with_topics.tsv.gz"

# %%
corpus_df = pd.read_csv(corpus_file, sep="\t", compression="gzip", index_col=0)
corpus_df.head(2)
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# /home/shinhan/github/plantbert/script_eda.ipynb Cell 5 line 1
# ----> <a href='vscode-notebook-cell://wsl%2Bubuntu-20.04/home/shinhan/github/plantbert/script_eda.ipynb#X14sdnNjb2RlLXJlbW90ZQ%3D%3D?line=0'>1</a> corpus_df = pd.read_csv(corpus_file, sep="\t", compression="gzip", index_col=0)
#       <a href='vscode-notebook-cell://wsl%2Bubuntu-20.04/home/shinhan/github/plantbert/script_eda.ipynb#X14sdnNjb2RlLXJlbW90ZQ%3D%3D?line=1'>2</a> corpus_df.head(2)
#
# File ~/miniconda3/envs/sklearn/lib/python3.10/site-packages/pandas/util/_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# File ~/miniconda3/envs/sklearn/lib/python3.10/site-packages/pandas/io/parsers/readers.py:680, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, error_bad_lines, warn_bad_lines, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     665 kwds_defaults = _refine_defaults_read(
#     666     dialect,
#     667     delimiter,
#    (...)
#     676     defaults={"delimiter": ","},
#     677 )
#     678 kwds.update(kwds_defaults)
# --> 680 return _read(filepath_or_buffer, kwds)
#
# File ~/miniconda3/envs/sklearn/lib/python3.10/site-packages/pandas/io/parsers/readers.py:581, in _read(filepath_or_buffer, kwds)
#     578     return parser
#     580 with parser:
# --> 581     return parser.read(nrows)
#
# File ~/miniconda3/envs/sklearn/lib/python3.10/site-packages/pandas/io/parsers/readers.py:1250, in TextFileReader.read(self, nrows)
#    1248 nrows = validate_integer("nrows", nrows)
#    1249 try:
# -> 1250     index, columns, col_dict = self._engine.read(nrows)
#    1251 except Exception:
#    1252     self.close()
#
# File ~/miniconda3/envs/sklearn/lib/python3.10/site-packages/pandas/io/parsers/c_parser_wrapper.py:225, in CParserWrapper.read(self, nrows)
#     223 try:
#     224     if self.low_memory:
# --> 225         chunks = self._reader.read_low_memory(nrows)
#     226         # destructive to chunks
#     227         data = _concatenate_chunks(chunks)
#
# File ~/miniconda3/envs/sklearn/lib/python3.10/site-packages/pandas/_libs/parsers.pyx:805, in pandas._libs.parsers.TextReader.read_low_memory()
#
# File ~/miniconda3/envs/sklearn/lib/python3.10/site-packages/pandas/_libs/parsers.pyx:861, in pandas._libs.parsers.TextReader._read_rows()
#
# File ~/miniconda3/envs/sklearn/lib/python3.10/site-packages/pandas/_libs/parsers.pyx:847, in pandas._libs.parsers.TextReader._tokenize_rows()
#
# File ~/miniconda3/envs/sklearn/lib/python3.10/site-packages/pandas/_libs/parsers.pyx:1960, in pandas._libs.parsers.raise_parser_error()
#
# ParserError: Error tokenizing data. C error: Calling read(nbytes) on source failed. Try engine='python'.

# %%
corpus_df.shape
# Out:
# (421307, 12)

# %% [markdown]
# ## ___Word counts___

# %% [markdown]
# ### Term frequency
#
# https://scikit-learn.org/stable/modules/generated/sklearn.feature_extraction.text.CountVectorizer.html

# %%
corpus     = corpus_df["Corpus"].tolist()

# %%
vect_count = CountVectorizer()

# CSR matrix with word frequency
X          = vect_count.fit_transform(corpus)

# %%
X.shape
# Out:
# (421307, 563704)

# %%
feat_names = vect_count.get_feature_names_out()

# %% [markdown]
# ### Check against vocabs
#
# The vocabs are from different dictionaries.

# %%
def check_overlap_with_vocab(feat_names, vocab_dir):

  feat_set    = set(feat_names)
  vocab_files = vocab_dir.glob("*.items")

  print("Vocab\t\tN_vocab\tN_intersect")
  dict_inter = {} # {vocab: intersect}
  for vocab_file in vocab_files:
    vocab = vocab_file.read_text().split("\n")
    vocab_set = set(vocab)
    intersect = list(feat_set.intersection(vocab_set))

    dict_inter[vocab_file.stem] = intersect

    print(f"{vocab_file.stem}\t{len(vocab)}\t{len(intersect)}")

# %%
dict_inter.keys()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /home/shinhan/github/plantbert/script_eda.ipynb Cell 15 line 1
# ----> <a href='vscode-notebook-cell://wsl%2Bubuntu-20.04/home/shinhan/github/plantbert/script_eda.ipynb#X25sdnNjb2RlLXJlbW90ZQ%3D%3D?line=0'>1</a> dict_inter.keys()
#
# NameError: name 'dict_inter' is not defined

# %%
# mostly homonyms, same sound and often the same spelling but differ in meaning
dict_inter["vocab_mth"]
# Out:
# ['cipher',
#  'balanced',
#  'translation',
#  'joule',
#  'chart',
#  'singleton',
#  'multivariate',
#  'trace',
#  'intersect',
#  'regression',
#  'prime',
#  'perigee',
#  'payoff',
#  'octagon',
#  'pairwise',
#  'mechanical',
#  'information',
#  'location',
#  'ceiling',
#  'expectation',
#  'bilinear',
#  'speed',
#  'quartiles',
#  'biometrics',
#  'rv',
#  'matching',
#  'permutation',
#  'pyramid',
#  'rad',
#  'particle',
#  'intersection',
#  'mensuration',
#  'composition',
#  'outlier',
#  'litre',
#  'divides',
#  'sup',
#  'jump',
#  'sheet',
#  'vanish',
#  'autocorrelation',
#  'optimal',
#  'residual',
#  'slope',
#  'homomorphism',
#  'observation',
#  'infeasible',
#  'inhomogeneous',
#  'statistic',
#  'revolve',
#  'hexagon',
#  'rise',
#  'octahedron',
#  'del',
#  'sign',
#  'anticlockwise',
#  'height',
#  'quantifier',
#  'applied',
#  'cycle',
#  'below',
#  'continuum',
#  'configuration',
#  'cylinder',
#  'instance',
#  'length',
#  'component',
#  'retardation',
#  'decagon',
#  'equivalent',
#  'cube',
#  'reciprocal',
#  'decile',
#  'contradiction',
#  'trillion',
#  'conformable',
#  'cylindroid',
#  'sum',
#  'consequent',
#  'sine',
#  'holomorphic',
#  'arithmetic',
#  'die',
#  'codeword',
#  'field',
#  'fulcrum',
#  'scale',
#  'generator',
#  'topology',
#  'abacus',
#  'symmetry',
#  'dimensions',
#  'denominator',
#  'valency',
#  'kurtosis',
#  'delta',
#  'member',
#  'cluster',
#  'triple',
#  'distinct',
#  'multiplicity',
#  'kinematics',
#  'interpolation',
#  'isometry',
#  'law',
#  'mean',
#  'multiple',
#  'confirm',
#  'equiprobable',
#  'nand',
#  'walk',
#  'model',
#  'net',
#  'reduce',
#  'time',
#  'multiplication',
#  'transformation',
#  'smooth',
#  'metre',
#  'diameter',
#  'semicircle',
#  'rearrangement',
#  'constant',
#  'numeral',
#  'convex',
#  'circumscribe',
#  'node',
#  'quotient',
#  'counts',
#  'antiparallel',
#  'source',
#  'harmonic',
#  'accuracy',
#  'focal',
#  'rod',
#  'sense',
#  'cuboid',
#  'serial',
#  'side',
#  'predicate',
#  'fluent',
#  'unknown',
#  'relation',
#  'trial',
#  'abscissa',
#  'cone',
#  'median',
#  'tessellation',
#  'determinant',
#  'int',
#  'round',
#  'analysis',
#  'covariance',
#  'space',
#  'declination',
#  'impulse',
#  'degree',
#  'kilogram',
#  'concavity',
#  'moment',
#  'triangulation',
#  'function',
#  'congruent',
#  'heteroscedastic',
#  'construct',
#  'homoscedastic',
#  'integral',
#  'perimeter',
#  'cut',
#  'body',
#  'isoclines',
#  'normal',
#  'algebra',
#  'increment',
#  'parentheses',
#  'injection',
#  'invalid',
#  'subfield',
#  'skewness',
#  'corollary',
#  'envelope',
#  'loop',
#  'infinite',
#  'circle',
#  'tangent',
#  'resolution',
#  'singular',
#  'blinding',
#  'compact',
#  'paraboloid',
#  'associative',
#  'discontinuity',
#  'element',
#  'resolve',
#  'hex',
#  'diverge',
#  'integration',
#  'chord',
#  'parabola',
#  'newton',
#  'thrust',
#  'meridian',
#  'trail',
#  'plane',
#  'subdivision',
#  'direction',
#  'morphism',
#  'connected',
#  'graph',
#  'software',
#  'antiprism',
#  'group',
#  'slack',
#  'stiffness',
#  'unit',
#  'discrete',
#  'latitude',
#  'inclination',
#  'hemisphere',
#  'correction',
#  'cardinality',
#  'basis',
#  'subset',
#  'cardioid',
#  'ratio',
#  'computer',
#  'converse',
#  'term',
#  'tables',
#  'hyperbola',
#  'subgroup',
#  'range',
#  'ring',
#  'solid',
#  'tetrahedron',
#  'causation',
#  'gradient',
#  'ellipsoid',
#  'simulation',
#  'composite',
#  'possible',
#  'conic',
#  'calculus',
#  'bifurcation',
#  'bijection',
#  'addition',
#  'compute',
#  'extension',
#  'ball',
#  'empirical',
#  'origin',
#  'simplify',
#  'representation',
#  'aggregate',
#  'energy',
#  'pascal',
#  'toppling',
#  'quantile',
#  'invariable',
#  'operator',
#  'lag',
#  'interval',
#  'figure',
#  'pi',
#  'isolate',
#  'symbol',
#  'period',
#  'intercept',
#  'figures',
#  'inference',
#  'plot',
#  'rotation',
#  'divergence',
#  'standardize',
#  'bar',
#  'risk',
#  'equator',
#  'bound',
#  'robust',
#  'cosine',
#  'metric',
#  'placebo',
#  'instantaneous',
#  'subgraph',
#  'not',
#  'infinity',
#  'one',
#  'selection',
#  '1526',
#  'abstraction',
#  'given',
#  'focus',
#  'code',
#  'greatest',
#  'detach',
#  'interior',
#  'spread',
#  'interest',
#  'polygon',
#  'validation',
#  'string',
#  'probability',
#  'edge',
#  'even',
#  'apse',
#  'lemma',
#  'tonne',
#  'trend',
#  'dynamics',
#  'face',
#  'ordinate',
#  'proportion',
#  'destinations',
#  'subtraction',
#  'adj',
#  'cap',
#  'dot',
#  'product',
#  'rounding',
#  'primitive',
#  'square',
#  'cofactor',
#  'polynomial',
#  'exact',
#  'compression',
#  'mathematics',
#  'convert',
#  'incidence',
#  'section',
#  'truncation',
#  'real',
#  'frame',
#  'solution',
#  'oscillations',
#  'encrypt',
#  'derivative',
#  'identity',
#  'numerator',
#  'diagonal',
#  'bivariate',
#  'saturated',
#  'approximate',
#  'inequality',
#  'computation',
#  'operation',
#  'initialize',
#  'limit',
#  'precision',
#  'segment',
#  'confidentiality',
#  'quadrilateral',
#  'ln',
#  'state',
#  'cusp',
#  'billion',
#  'reflection',
#  'domain',
#  'curl',
#  'infinitesimal',
#  'error',
#  'exponent',
#  'isomorphism',
#  'order',
#  'centre',
#  'concentric',
#  'coaxial',
#  'distributive',
#  'parity',
#  'restriction',
#  'elasticity',
#  'perpendicular',
#  'arrangement',
#  'countable',
#  'calculator',
#  'sd',
#  'strategy',
#  'cis',
#  'pair',
#  'tensor',
#  'include',
#  'degenerate',
#  'effort',
#  'positive',
#  'norm',
#  'proof',
#  'involution',
#  'gram',
#  'amp',
#  'mass',
#  'finite',
#  'variate',
#  'inflexion',
#  'centroid',
#  'surface',
#  'optimization',
#  'parameter',
#  'digit',
#  'correlation',
#  'friction',
#  'deduction',
#  'acre',
#  'incompatible',
#  'prism',
#  'example',
#  'displacement',
#  'neighbourhood',
#  'efficiency',
#  'emv',
#  'vector',
#  'angular',
#  'variable',
#  'indivisible',
#  'binomial',
#  'lamina',
#  'torus',
#  'sink',
#  'weight',
#  'exterior',
#  'event',
#  'strict',
#  'frustum',
#  'entry',
#  'enumeration',
#  'integrable',
#  'force',
#  'supplement',
#  'remainder',
#  'implication',
#  'root',
#  'minimum',
#  'index',
#  'theorem',
#  'paradox',
#  'transversal',
#  'clockwise',
#  'factorial',
#  'distance',
#  'pound',
#  'constraint',
#  'maximum',
#  'geodesic',
#  'acceleration',
#  'uniform',
#  'dilatation',
#  'arm',
#  'bearing',
#  'negation',
#  'series',
#  'divergent',
#  'characteristic',
#  'grade',
#  'elevation',
#  'phase',
#  'deviation',
#  'path',
#  'disjunction',
#  'kite',
#  'radius',
#  'game',
#  'watt',
#  'multinomial',
#  'inflection',
#  'scalar',
#  'projectile',
#  'minute',
#  'line',
#  'imply',
#  'resultant',
#  'shear',
#  'parametrization',
#  'eigenvalue',
#  'momentum',
#  'homogeneous',
#  'replicable',
#  'arc',
#  'axiom',
#  'negative',
#  'discriminant',
#  'isomorphic',
#  'equilibrium',
#  'biometry',
#  'digraph',
#  'substitution',
#  'pivot',
#  'odds',
#  'irreducible',
#  'density',
#  'decompose',
#  'population',
#  'omega',
#  'second',
#  'assumption',
#  'mapping',
#  'helix',
#  'correspondence',
#  'drag',
#  'apogee',
#  'determine',
#  'conjunction',
#  'counterexample',
#  'centesimal',
#  'inf',
#  'quadruple',
#  'frequency',
#  'resonance',
#  'implicit',
#  'capacity',
#  'adders',
#  'discretization',
#  'parallel',
#  'iteration',
#  'matrix',
#  'sequence',
#  'knot',
#  'rank',
#  'curvature',
#  'sector',
#  'observer',
#  'experiment',
#  'se',
#  'bimodal',
#  'nought',
#  'log',
#  'row',
#  'utility',
#  'axis',
#  'machine',
#  'set',
#  'equality',
#  'induction',
#  'dissection',
#  'integer',
#  'torque',
#  'fractal',
#  'contingent',
#  'phi',
#  'cycling',
#  'plus',
#  'exp',
#  'quantity',
#  'locus',
#  'gravity',
#  'quadrant',
#  'unity',
#  'perturbation',
#  'pressure',
#  'data',
#  'consistent',
#  'count',
#  'cryptography',
#  'bias',
#  'rationalize',
#  'reliability',
#  'exhaustive',
#  'genus',
#  'nominal',
#  'complement',
#  'and',
#  'trajectory',
#  'closed',
#  'estimate',
#  'array',
#  'ellipse',
#  'verification',
#  'revolution',
#  'subspace',
#  'representative',
#  'factor',
#  'diagram',
#  'lift',
#  'run',
#  'logarithm',
#  'estimation',
#  'kelvin',
#  'fraction',
#  'octant',
#  'floor',
#  'depression',
#  'quadric',
#  'equilateral',
#  'oblong',
#  'describe',
#  'power',
#  'amplitude',
#  'inconsistent',
#  'hardware',
#  'difference',
#  'circumference',
#  'discriminatory',
#  'agree',
#  'rectangle',
#  'bootstrapping',
#  'constants',
#  'decomposition',
#  'volume',
#  'hydrodynamics',
#  'random',
#  'derangement',
#  'antecedent',
#  'extrapolation',
#  'approximation',
#  'hypercube',
#  'geometry',
#  'similar',
#  'variance',
#  'value',
#  'hyp',
#  'hertz',
#  'ray',
#  'differentiation',
#  'closure',
#  'orbit',
#  'longitude',
#  'or',
#  'conclusion',
#  'wrt',
#  'leptokurtic',
#  'disk',
#  'kg',
#  'argument',
#  'least',
#  'equation',
#  'branch',
#  'velocity',
#  'scheduling',
#  'separable',
#  'image',
#  'couple',
#  'express',
#  'tree',
#  'curve',
#  'calculate',
#  'partition',
#  'df',
#  'rectangular',
#  'codomain',
#  'octal',
#  'trim',
#  'hectare',
#  'randomize',
#  'sample',
#  'tableau',
#  'bc',
#  'digital',
#  'heuristic',
#  'collinear',
#  'exclusive',
#  'statistics',
#  'independent',
#  'arg',
#  'feasible',
#  'light',
#  'midpoint',
#  'ideal',
#  'collision',
#  'accurate',
#  'fit',
#  'mode',
#  'stress',
#  'spring',
#  'region',
#  'replication',
#  'complementary',
#  'pendulum',
#  'sphere',
#  'altitude',
#  'family',
#  'bit',
#  'point',
#  'mechanics',
#  'divisible',
#  'cubic',
#  'apex',
#  'asymmetric',
#  'control',
#  'quaternion',
#  'elastic',
#  'div',
#  'flag',
#  'transpose',
#  'redundant',
#  'noise',
#  'load',
#  'extremum',
#  'distribution',
#  'statement',
#  'division',
#  'ad',
#  'union',
#  'disjoint',
#  'osculation',
#  'dihedral',
#  'multicollinearity',
#  'cancel',
#  'insoluble',
#  'rhombus',
#  'annulus',
#  'quadrangle',
#  'sgn',
#  'deceleration',
#  'network',
#  'equate',
#  'lever',
#  'cypher',
#  'tiling',
#  'chaos',
#  'concyclic',
#  'polyhedron',
#  'tension',
#  'extrapolate',
#  'simplex',
#  'base',
#  'histogram',
#  'tie',
#  'coincident',
#  'inertia',
#  'asymptote',
#  'frontier',
#  'fallacy',
#  'coefficient',
#  'stability',
#  'im',
#  'logic',
#  'centigrade',
#  'percentage',
#  'cup',
#  'triangle',
#  'magnitude',
#  'estimator',
#  'invariant',
#  'angle',
#  'projection',
#  'above',
#  'combination',
#  'beats',
#  'analytic',
#  'evaluate',
#  'conjugate',
#  'oblique',
#  'parallelepiped',
#  'eccentricity',
#  'converge',
#  'vertex',
#  'icosahedron',
#  'computable',
#  'disc',
#  'area',
#  'progression',
#  'canonical',
#  'spiral',
#  'framework',
#  'subtend',
#  'epsilon',
#  'proposition',
#  'equidistant',
#  'platykurtic',
#  'dodecahedron',
#  'dispersion',
#  'brackets',
#  'diamond',
#  'congruence',
#  'ton',
#  'sigma',
#  'coordinates',
#  'rose',
#  'measure',
#  'algorithm',
#  'radian',
#  'percentile',
#  'direct',
#  'postulate',
#  'expansion',
#  'perspective',
#  'conditional',
#  'association',
#  'iff',
#  'expand',
#  'raise',
#  'concurrent']

# %% [markdown]
# ## ___Tf-Idf___

# %%
vect_tfidf = TfidfVectorizer(lowercase=False,
                             ngram_range=(1,3),
                             stop_words="english")

# %%
X_tfidf = vect_tfidf.fit_transform(corpus)
# Out:
# The Kernel crashed while executing code in the the current cell or a previous cell. Please review the code in the cell(s) to identify a possible cause of the failure. Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info. View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
feat_tfidf_names = vect_tfidf.get_feature_names_out()
feat_tfidf_set   = set(feat_tfidf_names)
