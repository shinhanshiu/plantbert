# %% [markdown]
# # __BERT retrain__
#
# Modified from [the Python Code](https://thepythoncode.com/article/pretraining-bert-huggingface-transformers-in-python)
# - [Google Colab](https://colab.research.google.com/drive/1An1VNpKKMRVrwcdQQNSe7Omh_fl2Gj-2?usp=sharing&pli=1#scrollTo=-CVoZ3bC_j6K)

# %% [markdown]
# ## ___Setup___

# %% [markdown]
# ### Install
#
# ```bash
# conda create -n bert python
# conda activate bert
# ```

# %%
#%pip install datasets transformers==4.11.2 sentencepiece
# %pip install datasets transformers sentencepiece
# %pip install ipywidgets
# %pip install pytest
# %pip install xformers
# %pip install session_info
# %pip install accelerate -U
# Out:
# Requirement already satisfied: datasets in /home/shius/miniconda3/envs/bert/lib/python3.11/site-packages (2.14.5)
# Requirement already satisfied: transformers in /home/shius/miniconda3/envs/bert/lib/python3.11/site-packages (4.33.3)
# Requirement already satisfied: sentencepiece in /home/shius/miniconda3/envs/bert/lib/python3.11/site-packages (0.1.99)
# Requirement already satisfied: numpy>=1.17 in /home/shius/miniconda3/envs/bert/lib/python3.11/site-packages (from datasets) (1.26.0)
# Requirement already satisfied: pyarrow>=8.0.0 in /home/shius/miniconda3/envs/bert/lib/python3.11/site-packages (from datasets) (13.0.0)
# Requirement already satisfied: dill<0.3.8,>=0.3.0 in /home/shius/miniconda3/envs/bert/lib/python3.11/site-packages (from datasets) (0.3.7)
# Requirement already satisfied: pandas in /home/shius/miniconda3/envs/bert/lib/python3.11/site-packages (from datasets) (2.1.1)
# Requirement already satisfied: requests>=2.19.0 in /home/shius/miniconda3/envs/bert/lib/python3.11/site-packages (from datasets) (2.31.0)
# Requirement already satisfied: tqdm>=4.62.1 in /home/shius/miniconda3/envs/bert/lib/python3.11/site-packages (from datasets) (4.66.1)
# Requirement already satisfied: xxhash in /home/shius/miniconda3/envs/bert/lib/python3.11/site-packages (from datasets) (3.3.0)
# Requirement already satisfied: multiprocess in /home/shius/miniconda3/envs/bert/lib/python3.11/site-packages (from datasets) (0.70.15)
# Requirement already satisfied: fsspec[http]<2023.9.0,>=2023.1.0 in /home/shius/miniconda3/envs/bert/lib/python3.11/site-packages (from datasets) (2023.6.0)
# Requirement already satisfied: aiohttp in /home/shius/miniconda3/envs/bert/lib/python3.11/site-packages (from datasets) (3.8.5)
# Requirement already satisfied: huggingface-hub<1.0.0,>=0.14.0 in /home/shius/miniconda3/envs/bert/lib/python3.11/site-packages (from datasets) (0.17.3)
# Requirement already satisfied: packaging in /home/shius/miniconda3/envs/bert/lib/python3.11/site-packages (from datasets) (23.2)
# Requirement already satisfied: pyyaml>=5.1 in /home/shius/miniconda3/envs/bert/lib/python3.11/site-packages (from datasets) (6.0.1)
# Requirement already satisfied: filelock in /home/shius/miniconda3/envs/bert/lib/python3.11/site-packages (from transformers) (3.12.4)
# Requirement already satisfied: regex!=2019.12.17 in /home/shius/miniconda3/envs/bert/lib/python3.11/site-packages (from transformers) (2023.8.8)
# Requirement already satisfied: tokenizers!=0.11.3,<0.14,>=0.11.1 in /home/shius/miniconda3/envs/bert/lib/python3.11/site-packages (from transformers) (0.13.3)
# Requirement already satisfied: safetensors>=0.3.1 in /home/shius/miniconda3/envs/bert/lib/python3.11/site-packages (from transformers) (0.3.3)
# Requirement already satisfied: attrs>=17.3.0 in /home/shius/miniconda3/envs/bert/lib/python3.11/site-packages (from aiohttp->datasets) (23.1.0)
# Requirement already satisfied: charset-normalizer<4.0,>=2.0 in /home/shius/miniconda3/envs/bert/lib/python3.11/site-packages (from aiohttp->datasets) (3.3.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /home/shius/miniconda3/envs/bert/lib/python3.11/site-packages (from aiohttp->datasets) (6.0.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /home/shius/miniconda3/envs/bert/lib/python3.11/site-packages (from aiohttp->datasets) (4.0.3)
# Requirement already satisfied: yarl<2.0,>=1.0 in /home/shius/miniconda3/envs/bert/lib/python3.11/site-packages (from aiohttp->datasets) (1.9.2)
# Requirement already satisfied: frozenlist>=1.1.1 in /home/shius/miniconda3/envs/bert/lib/python3.11/site-packages (from aiohttp->datasets) (1.4.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /home/shius/miniconda3/envs/bert/lib/python3.11/site-packages (from aiohttp->datasets) (1.3.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /home/shius/miniconda3/envs/bert/lib/python3.11/site-packages (from huggingface-hub<1.0.0,>=0.14.0->datasets) (4.8.0)
# Requirement already satisfied: idna<4,>=2.5 in /home/shius/miniconda3/envs/bert/lib/python3.11/site-packages (from requests>=2.19.0->datasets) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/shius/miniconda3/envs/bert/lib/python3.11/site-packages (from requests>=2.19.0->datasets) (2.0.5)
# Requirement already satisfied: certifi>=2017.4.17 in /home/shius/miniconda3/envs/bert/lib/python3.11/site-packages (from requests>=2.19.0->datasets) (2023.7.22)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/shius/miniconda3/envs/bert/lib/python3.11/site-packages (from pandas->datasets) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /home/shius/miniconda3/envs/bert/lib/python3.11/site-packages (from pandas->datasets) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in /home/shius/miniconda3/envs/bert/lib/python3.11/site-packages (from pandas->datasets) (2023.3)
# Requirement already satisfied: six>=1.5 in /home/shius/miniconda3/envs/bert/lib/python3.11/site-packages (from python-dateutil>=2.8.2->pandas->datasets) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: ipywidgets in /home/shius/miniconda3/envs/bert/lib/python3.11/site-packages (8.1.1)
# Requirement already satisfied: comm>=0.1.3 in /home/shius/miniconda3/envs/bert/lib/python3.11/site-packages (from ipywidgets) (0.1.4)
# Requirement already satisfied: ipython>=6.1.0 in /home/shius/miniconda3/envs/bert/lib/python3.11/site-packages (from ipywidgets) (8.16.0)
# Requirement already satisfied: traitlets>=4.3.1 in /home/shius/miniconda3/envs/bert/lib/python3.11/site-packages (from ipywidgets) (5.10.1)
# Requirement already satisfied: widgetsnbextension~=4.0.9 in /home/shius/miniconda3/envs/bert/lib/python3.11/site-packages (from ipywidgets) (4.0.9)
# Requirement already satisfied: jupyterlab-widgets~=3.0.9 in /home/shius/miniconda3/envs/bert/lib/python3.11/site-packages (from ipywidgets) (3.0.9)
# Requirement already satisfied: backcall in /home/shius/miniconda3/envs/bert/lib/python3.11/site-packages (from ipython>=6.1.0->ipywidgets) (0.2.0)
# Requirement already satisfied: decorator in /home/shius/miniconda3/envs/bert/lib/python3.11/site-packages (from ipython>=6.1.0->ipywidgets) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in /home/shius/miniconda3/envs/bert/lib/python3.11/site-packages (from ipython>=6.1.0->ipywidgets) (0.19.0)
# Requirement already satisfied: matplotlib-inline in /home/shius/miniconda3/envs/bert/lib/python3.11/site-packages (from ipython>=6.1.0->ipywidgets) (0.1.6)
# Requirement already satisfied: pickleshare in /home/shius/miniconda3/envs/bert/lib/python3.11/site-packages (from ipython>=6.1.0->ipywidgets) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30 in /home/shius/miniconda3/envs/bert/lib/python3.11/site-packages (from ipython>=6.1.0->ipywidgets) (3.0.39)
# Requirement already satisfied: pygments>=2.4.0 in /home/shius/miniconda3/envs/bert/lib/python3.11/site-packages (from ipython>=6.1.0->ipywidgets) (2.16.1)
# Requirement already satisfied: stack-data in /home/shius/miniconda3/envs/bert/lib/python3.11/site-packages (from ipython>=6.1.0->ipywidgets) (0.6.2)
# Requirement already satisfied: pexpect>4.3 in /home/shius/miniconda3/envs/bert/lib/python3.11/site-packages (from ipython>=6.1.0->ipywidgets) (4.8.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in /home/shius/miniconda3/envs/bert/lib/python3.11/site-packages (from jedi>=0.16->ipython>=6.1.0->ipywidgets) (0.8.3)
# Requirement already satisfied: ptyprocess>=0.5 in /home/shius/miniconda3/envs/bert/lib/python3.11/site-packages (from pexpect>4.3->ipython>=6.1.0->ipywidgets) (0.7.0)
# Requirement already satisfied: wcwidth in /home/shius/miniconda3/envs/bert/lib/python3.11/site-packages (from prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30->ipython>=6.1.0->ipywidgets) (0.2.7)
# Requirement already satisfied: executing>=1.2.0 in /home/shius/miniconda3/envs/bert/lib/python3.11/site-packages (from stack-data->ipython>=6.1.0->ipywidgets) (1.2.0)
# Requirement already satisfied: asttokens>=2.1.0 in /home/shius/miniconda3/envs/bert/lib/python3.11/site-packages (from stack-data->ipython>=6.1.0->ipywidgets) (2.4.0)
# Requirement already satisfied: pure-eval in /home/shius/miniconda3/envs/bert/lib/python3.11/site-packages (from stack-data->ipython>=6.1.0->ipywidgets) (0.2.2)
# Requirement already satisfied: six>=1.12.0 in /home/shius/miniconda3/envs/bert/lib/python3.11/site-packages (from asttokens>=2.1.0->stack-data->ipython>=6.1.0->ipywidgets) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: pytest in /home/shius/miniconda3/envs/bert/lib/python3.11/site-packages (7.4.2)
# Requirement already satisfied: iniconfig in /home/shius/miniconda3/envs/bert/lib/python3.11/site-packages (from pytest) (2.0.0)
# Requirement already satisfied: packaging in /home/shius/miniconda3/envs/bert/lib/python3.11/site-packages (from pytest) (23.2)
# Requirement already satisfied: pluggy<2.0,>=0.12 in /home/shius/miniconda3/envs/bert/lib/python3.11/site-packages (from pytest) (1.3.0)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: xformers in /home/shius/miniconda3/envs/bert/lib/python3.11/site-packages (0.0.22)
# Requirement already satisfied: numpy in /home/shius/miniconda3/envs/bert/lib/python3.11/site-packages (from xformers) (1.26.0)
# Requirement already satisfied: torch==2.0.1 in /home/shius/miniconda3/envs/bert/lib/python3.11/site-packages (from xformers) (2.0.1)
# Requirement already satisfied: filelock in /home/shius/miniconda3/envs/bert/lib/python3.11/site-packages (from torch==2.0.1->xformers) (3.12.4)
# Requirement already satisfied: typing-extensions in /home/shius/miniconda3/envs/bert/lib/python3.11/site-packages (from torch==2.0.1->xformers) (4.8.0)
# Requirement already satisfied: sympy in /home/shius/miniconda3/envs/bert/lib/python3.11/site-packages (from torch==2.0.1->xformers) (1.12)
# Requirement already satisfied: networkx in /home/shius/miniconda3/envs/bert/lib/python3.11/site-packages (from torch==2.0.1->xformers) (3.1)
# Requirement already satisfied: jinja2 in /home/shius/miniconda3/envs/bert/lib/python3.11/site-packages (from torch==2.0.1->xformers) (3.1.2)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu11==11.7.99 in /home/shius/miniconda3/envs/bert/lib/python3.11/site-packages (from torch==2.0.1->xformers) (11.7.99)
# Requirement already satisfied: nvidia-cuda-runtime-cu11==11.7.99 in /home/shius/miniconda3/envs/bert/lib/python3.11/site-packages (from torch==2.0.1->xformers) (11.7.99)
# Requirement already satisfied: nvidia-cuda-cupti-cu11==11.7.101 in /home/shius/miniconda3/envs/bert/lib/python3.11/site-packages (from torch==2.0.1->xformers) (11.7.101)
# Requirement already satisfied: nvidia-cudnn-cu11==8.5.0.96 in /home/shius/miniconda3/envs/bert/lib/python3.11/site-packages (from torch==2.0.1->xformers) (8.5.0.96)
# Requirement already satisfied: nvidia-cublas-cu11==11.10.3.66 in /home/shius/miniconda3/envs/bert/lib/python3.11/site-packages (from torch==2.0.1->xformers) (11.10.3.66)
# Requirement already satisfied: nvidia-cufft-cu11==10.9.0.58 in /home/shius/miniconda3/envs/bert/lib/python3.11/site-packages (from torch==2.0.1->xformers) (10.9.0.58)
# Requirement already satisfied: nvidia-curand-cu11==10.2.10.91 in /home/shius/miniconda3/envs/bert/lib/python3.11/site-packages (from torch==2.0.1->xformers) (10.2.10.91)
# Requirement already satisfied: nvidia-cusolver-cu11==11.4.0.1 in /home/shius/miniconda3/envs/bert/lib/python3.11/site-packages (from torch==2.0.1->xformers) (11.4.0.1)
# Requirement already satisfied: nvidia-cusparse-cu11==11.7.4.91 in /home/shius/miniconda3/envs/bert/lib/python3.11/site-packages (from torch==2.0.1->xformers) (11.7.4.91)
# Requirement already satisfied: nvidia-nccl-cu11==2.14.3 in /home/shius/miniconda3/envs/bert/lib/python3.11/site-packages (from torch==2.0.1->xformers) (2.14.3)
# Requirement already satisfied: nvidia-nvtx-cu11==11.7.91 in /home/shius/miniconda3/envs/bert/lib/python3.11/site-packages (from torch==2.0.1->xformers) (11.7.91)
# Requirement already satisfied: triton==2.0.0 in /home/shius/miniconda3/envs/bert/lib/python3.11/site-packages (from torch==2.0.1->xformers) (2.0.0)
# Requirement already satisfied: setuptools in /home/shius/miniconda3/envs/bert/lib/python3.11/site-packages (from nvidia-cublas-cu11==11.10.3.66->torch==2.0.1->xformers) (68.0.0)
# Requirement already satisfied: wheel in /home/shius/miniconda3/envs/bert/lib/python3.11/site-packages (from nvidia-cublas-cu11==11.10.3.66->torch==2.0.1->xformers) (0.41.2)
# Requirement already satisfied: cmake in /home/shius/miniconda3/envs/bert/lib/python3.11/site-packages (from triton==2.0.0->torch==2.0.1->xformers) (3.27.6)
# Requirement already satisfied: lit in /home/shius/miniconda3/envs/bert/lib/python3.11/site-packages (from triton==2.0.0->torch==2.0.1->xformers) (17.0.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/shius/miniconda3/envs/bert/lib/python3.11/site-packages (from jinja2->torch==2.0.1->xformers) (2.1.3)
# Requirement already satisfied: mpmath>=0.19 in /home/shius/miniconda3/envs/bert/lib/python3.11/site-packages (from sympy->torch==2.0.1->xformers) (1.3.0)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: session_info in /home/shius/miniconda3/envs/bert/lib/python3.11/site-packages (1.0.0)
# Requirement already satisfied: stdlib-list in /home/shius/miniconda3/envs/bert/lib/python3.11/site-packages (from session_info) (0.9.0)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: accelerate in /home/shius/miniconda3/envs/bert/lib/python3.11/site-packages (0.23.0)
# Requirement already satisfied: numpy>=1.17 in /home/shius/miniconda3/envs/bert/lib/python3.11/site-packages (from accelerate) (1.26.0)
# Requirement already satisfied: packaging>=20.0 in /home/shius/miniconda3/envs/bert/lib/python3.11/site-packages (from accelerate) (23.2)
# Requirement already satisfied: psutil in /home/shius/miniconda3/envs/bert/lib/python3.11/site-packages (from accelerate) (5.9.0)
# Requirement already satisfied: pyyaml in /home/shius/miniconda3/envs/bert/lib/python3.11/site-packages (from accelerate) (6.0.1)
# Requirement already satisfied: torch>=1.10.0 in /home/shius/miniconda3/envs/bert/lib/python3.11/site-packages (from accelerate) (2.0.1)
# Requirement already satisfied: huggingface-hub in /home/shius/miniconda3/envs/bert/lib/python3.11/site-packages (from accelerate) (0.17.3)
# Requirement already satisfied: filelock in /home/shius/miniconda3/envs/bert/lib/python3.11/site-packages (from torch>=1.10.0->accelerate) (3.12.4)
# Requirement already satisfied: typing-extensions in /home/shius/miniconda3/envs/bert/lib/python3.11/site-packages (from torch>=1.10.0->accelerate) (4.8.0)
# Requirement already satisfied: sympy in /home/shius/miniconda3/envs/bert/lib/python3.11/site-packages (from torch>=1.10.0->accelerate) (1.12)
# Requirement already satisfied: networkx in /home/shius/miniconda3/envs/bert/lib/python3.11/site-packages (from torch>=1.10.0->accelerate) (3.1)
# Requirement already satisfied: jinja2 in /home/shius/miniconda3/envs/bert/lib/python3.11/site-packages (from torch>=1.10.0->accelerate) (3.1.2)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu11==11.7.99 in /home/shius/miniconda3/envs/bert/lib/python3.11/site-packages (from torch>=1.10.0->accelerate) (11.7.99)
# Requirement already satisfied: nvidia-cuda-runtime-cu11==11.7.99 in /home/shius/miniconda3/envs/bert/lib/python3.11/site-packages (from torch>=1.10.0->accelerate) (11.7.99)
# Requirement already satisfied: nvidia-cuda-cupti-cu11==11.7.101 in /home/shius/miniconda3/envs/bert/lib/python3.11/site-packages (from torch>=1.10.0->accelerate) (11.7.101)
# Requirement already satisfied: nvidia-cudnn-cu11==8.5.0.96 in /home/shius/miniconda3/envs/bert/lib/python3.11/site-packages (from torch>=1.10.0->accelerate) (8.5.0.96)
# Requirement already satisfied: nvidia-cublas-cu11==11.10.3.66 in /home/shius/miniconda3/envs/bert/lib/python3.11/site-packages (from torch>=1.10.0->accelerate) (11.10.3.66)
# Requirement already satisfied: nvidia-cufft-cu11==10.9.0.58 in /home/shius/miniconda3/envs/bert/lib/python3.11/site-packages (from torch>=1.10.0->accelerate) (10.9.0.58)
# Requirement already satisfied: nvidia-curand-cu11==10.2.10.91 in /home/shius/miniconda3/envs/bert/lib/python3.11/site-packages (from torch>=1.10.0->accelerate) (10.2.10.91)
# Requirement already satisfied: nvidia-cusolver-cu11==11.4.0.1 in /home/shius/miniconda3/envs/bert/lib/python3.11/site-packages (from torch>=1.10.0->accelerate) (11.4.0.1)
# Requirement already satisfied: nvidia-cusparse-cu11==11.7.4.91 in /home/shius/miniconda3/envs/bert/lib/python3.11/site-packages (from torch>=1.10.0->accelerate) (11.7.4.91)
# Requirement already satisfied: nvidia-nccl-cu11==2.14.3 in /home/shius/miniconda3/envs/bert/lib/python3.11/site-packages (from torch>=1.10.0->accelerate) (2.14.3)
# Requirement already satisfied: nvidia-nvtx-cu11==11.7.91 in /home/shius/miniconda3/envs/bert/lib/python3.11/site-packages (from torch>=1.10.0->accelerate) (11.7.91)
# Requirement already satisfied: triton==2.0.0 in /home/shius/miniconda3/envs/bert/lib/python3.11/site-packages (from torch>=1.10.0->accelerate) (2.0.0)
# Requirement already satisfied: setuptools in /home/shius/miniconda3/envs/bert/lib/python3.11/site-packages (from nvidia-cublas-cu11==11.10.3.66->torch>=1.10.0->accelerate) (68.0.0)
# Requirement already satisfied: wheel in /home/shius/miniconda3/envs/bert/lib/python3.11/site-packages (from nvidia-cublas-cu11==11.10.3.66->torch>=1.10.0->accelerate) (0.41.2)
# Requirement already satisfied: cmake in /home/shius/miniconda3/envs/bert/lib/python3.11/site-packages (from triton==2.0.0->torch>=1.10.0->accelerate) (3.27.6)
# Requirement already satisfied: lit in /home/shius/miniconda3/envs/bert/lib/python3.11/site-packages (from triton==2.0.0->torch>=1.10.0->accelerate) (17.0.1)
# Requirement already satisfied: fsspec in /home/shius/miniconda3/envs/bert/lib/python3.11/site-packages (from huggingface-hub->accelerate) (2023.6.0)
# Requirement already satisfied: requests in /home/shius/miniconda3/envs/bert/lib/python3.11/site-packages (from huggingface-hub->accelerate) (2.31.0)
# Requirement already satisfied: tqdm>=4.42.1 in /home/shius/miniconda3/envs/bert/lib/python3.11/site-packages (from huggingface-hub->accelerate) (4.66.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/shius/miniconda3/envs/bert/lib/python3.11/site-packages (from jinja2->torch>=1.10.0->accelerate) (2.1.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/shius/miniconda3/envs/bert/lib/python3.11/site-packages (from requests->huggingface-hub->accelerate) (3.3.0)
# Requirement already satisfied: idna<4,>=2.5 in /home/shius/miniconda3/envs/bert/lib/python3.11/site-packages (from requests->huggingface-hub->accelerate) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/shius/miniconda3/envs/bert/lib/python3.11/site-packages (from requests->huggingface-hub->accelerate) (2.0.5)
# Requirement already satisfied: certifi>=2017.4.17 in /home/shius/miniconda3/envs/bert/lib/python3.11/site-packages (from requests->huggingface-hub->accelerate) (2023.7.22)
# Requirement already satisfied: mpmath>=0.19 in /home/shius/miniconda3/envs/bert/lib/python3.11/site-packages (from sympy->torch>=1.10.0->accelerate) (1.3.0)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ### Import

# %%
import os, json, session_info
import pandas as pd
from pathlib import Path
from datasets import Dataset
from transformers import BertTokenizerFast, BertConfig, BertForMaskedLM, \
                         DataCollatorForLanguageModeling, TrainingArguments, \
                         Trainer, pipeline
from tokenizers import BertWordPieceTokenizer

# %% [markdown]
# ### Folders and rand_seed

# %%
rand_seed = 20231002

work_dir = Path.home() / "projects/plantbert"
work_dir.mkdir(parents=True, exist_ok=True)

corpus_file = work_dir / "corpus_with_topics.tsv.gz"

model_dir = work_dir / "models"
model_dir.mkdir(parents=True, exist_ok=True)

os.chdir(work_dir)
print("cwd:", os.getcwd())
# Out:
# cwd: /mnt/d/projects/plantbert

# %%
# write_req_file only write imported modules
session_info.show(na=True, jupyter=True, dependencies=True, html=False,
                  write_req_file=True)
# Out:
# -----
# datasets            2.14.5
# pandas              2.1.1
# session_info        1.0.0
# tokenizers          0.13.3
# transformers        4.33.3
# -----
# accelerate          0.23.0
# aiohttp             3.8.5
# aiosignal           1.3.1
# asttokens           NA
# async_timeout       4.0.3
# attr                23.1.0
# backcall            0.2.0
# certifi             2023.07.22
# charset_normalizer  3.3.0
# comm                0.1.4
# cython_runtime      NA
# dateutil            2.8.2
# debugpy             1.6.7
# decorator           5.1.1
# dill                0.3.7
# executing           1.2.0
# filelock            3.12.4
# frozenlist          1.4.0
# fsspec              2023.6.0
# huggingface_hub     0.17.3
# idna                3.4
# ipykernel           6.25.2
# ipywidgets          8.1.1
# jedi                0.19.0
# mpmath              1.3.0
# multidict           6.0.4
# multiprocess        0.70.15
# numpy               1.26.0
# nvfuser             NA
# packaging           23.2
# parso               0.8.3
# pexpect             4.8.0
# pickleshare         0.7.5
# pkg_resources       NA
# platformdirs        3.10.0
# prompt_toolkit      3.0.39
# psutil              5.9.0
# ptyprocess          0.7.0
# pure_eval           0.2.2
# pyarrow             13.0.0
# pydev_ipython       NA
# pydevconsole        NA
# pydevd              2.9.5
# pydevd_file_utils   NA
# pydevd_plugins      NA
# pydevd_tracing      NA
# pygments            2.16.1
# pytz                2023.3.post1
# requests            2.31.0
# safetensors         0.3.3
# sentencepiece       0.1.99
# six                 1.16.0
# stack_data          0.6.2
# swig_runtime_data4  NA
# sympy               1.12
# torch               2.0.1+cu117
# tornado             6.3.2
# tqdm                4.66.1
# traitlets           5.10.1
# typing_extensions   NA
# urllib3             2.0.5
# wcwidth             0.2.7
# xxhash              NA
# yaml                6.0.1
# yarl                1.9.2
# zmq                 25.1.0
# -----
# IPython             8.16.0
# jupyter_client      8.3.1
# jupyter_core        5.3.2
# -----
# Python 3.11.5 (main, Sep 11 2023, 13:54:46) [GCC 11.2.0]
# Linux-5.15.90.1-microsoft-standard-WSL2-x86_64-with-glibc2.31
# -----
# Session information updated at 2023-10-03 10:44

# %% [markdown]
# ## ___Process raw data___
#
# Info on dataset creation
# - [Hugging face dataset creation](https://huggingface.co/docs/datasets/create_dataset)
# - [Huggingface NLP course](https://huggingface.co/learn/nlp-course/chapter5/5)
# - [Pd dataframe to dataset](https://discuss.huggingface.co/t/from-pandas-dataframe-to-huggingface-dataset/9322)
#
# Corpus: table4_2_corpus_with_topic_assignment.tsv
# - This is from the plant science history project consisted of 421658 PubMed entries classified as plant science papers.

# %% [markdown]
# ### Convert corpus to dataset
#
# Steps
# - gz to Pandas DataFrame
# - dataframe to dataset

# %%
# Read gz as a pandas dataframe
corpus = pd.read_csv(corpus_file, sep="\t", compression="gzip")
corpus.head(2)
# Out:
#    Unnamed: 0  Index_1385417  PMID        Date                        Journal  \
# 0           0              3    61  1975-12-11  Biochimica et biophysica acta
# 1           1              4    67  1975-11-20  Biochimica et biophysica acta
#
#                                                Title  \
# 0  Identification of the 120 mus phase in the dec...
# 1  Cholinesterases from plant tissues. VI. Prelim...
#
#                                             Abstract Initial filter qualifier  \
# 0  After a 500 mus laser flash a 120 mus phase in...                  spinach
# 1  Enzymes capable of hydrolyzing esters of thioc...                    plant
#
#                                               Corpus  reg_article  \
# 0  Identification of the 120 mus phase in the dec...            1
# 1  Cholinesterases from plant tissues. VI. Prelim...            1
#
#    Text classification score  \
# 0                   0.716394
# 1                   0.894874
#
#                                  Preprocessed corpus  Topic
# 0  identification 120 mus phase decay delayed flu...     52
# 1  cholinesterases plant tissues . vi . prelimina...     48

# %%
# Only take the txt column
corpus_txt = corpus[["Corpus", "Topic"]]
corpus_txt.columns = ["text", "label"]
corpus_txt.shape
# Out:
# (421307, 2)

# %%
# Create a dataset from the pandas dataframe
dataset = Dataset.from_pandas(corpus_txt)
dataset
# Out:
# Dataset({
#     features: ['text', 'label'],
#     num_rows: 421307
# })

# %% [markdown]
# ### Split train/test

# %%
# split the dataset into training (90%) and testing (10%)
d = dataset.train_test_split(test_size=0.1, seed=rand_seed)

d["train"], d["test"]
# Out:
# (Dataset({
#      features: ['text', 'label'],
#      num_rows: 379176
#  }),
#  Dataset({
#      features: ['text', 'label'],
#      num_rows: 42131
#  }))

# %%
for t in d["train"]["text"][:3]:
  print(t[:50],"...")
# Out:
# Chlorophyll degradation during senescence. The cat ...
# vsiRNAs derived from the miRNA-generating sites of ...
# Postharvest physiology and technology  of loquat ( ...

# %% [markdown]
# ### Dataset to text for training tokenizer

# %%
def dataset_to_text(dataset, output_filename="data.txt"):
  """Utility function to save dataset text to disk, useful for using the texts 
  to train the tokenizer (as the tokenizer accepts files)"""
  with open(output_filename, "w") as f:
    for t in dataset["text"]:
      print(t, file=f)

# save the training set to train.txt
dataset_to_text(d["train"], "train.txt")

# save the testing set to test.txt
dataset_to_text(d["test"], "test.txt")

# %% [markdown]
# ## ___Tokenize datasets___

# %% [markdown]
# ### Settings
#
# Encode with trucation is defult.

# %%
special_tokens = ["[PAD]", "[UNK]", "[CLS]", "[SEP]", "[MASK]", "<S>", "<T>"]

# training the tokenizer on the training set
files = ["train.txt"]

# 30,522 vocab is BERT's default vocab size, feel free to tweak
vocab_size = 30_522

# maximum sequence length, lowering will result to faster training (when increasing batch size)
max_length = 512

# %% [markdown]
# ### Train and save tokenizer
#
# Also see [this code](https://github.com/huggingface/tokenizers/blob/main/bindings/python/examples/train_bert_wordpiece.py)

# %%
# initialize the WordPiece tokenizer
tokenizer = BertWordPieceTokenizer()

# train the tokenizer
tokenizer.train(files=files, vocab_size=vocab_size, special_tokens=special_tokens)

# enable truncation up to the maximum 512 tokens
tokenizer.enable_truncation(max_length=max_length)

# %%
# save the tokenizer  
tokenizer.save_model(str(model_dir))
# Out:
# ['/home/shius/projects/plantbert/models/vocab.txt']

# %%
# dumping some of the tokenizer config to config file, 
# including special tokens, whether to lower case and the maximum sequence length
with open(os.path.join(model_dir, "config.json"), "w") as f:
  tokenizer_cfg = {
      "do_lower_case": True,
      "unk_token": "[UNK]",
      "sep_token": "[SEP]",
      "pad_token": "[PAD]",
      "cls_token": "[CLS]",
      "mask_token": "[MASK]",
      "model_max_length": max_length,
      "max_len": max_length,
  }
  json.dump(tokenizer_cfg, f)

# %% [markdown]
# ### Tokenize dataset

# %%
# when the tokenizer is trained and configured, load it as BertTokenizerFast
btz_tokenizer = BertTokenizerFast.from_pretrained(model_dir)

# %%
def encode(examples):
  """Mapping function to tokenize the sentences passed with truncation"""
  return btz_tokenizer(examples["text"], 
                   truncation=True, 
                   padding="max_length", 
                   max_length=max_length, 
                   return_special_tokens_mask=True)

# %%
# tokenizing the train dataset
train_dataset = d["train"].map(encode, batched=True)

# tokenizing the testing dataset
test_dataset = d["test"].map(encode, batched=True)
# Out:
# Map:   0%|          | 0/379492 [00:00<?, ? examples/s]
# Map:   0%|          | 0/42166 [00:00<?, ? examples/s]

# %% [markdown]
# ## ___Retrain BERT___

# %% [markdown]
# ### Set format

# %%
train_dataset.set_format(type="torch", columns=["input_ids", "attention_mask"])
test_dataset.set_format(type="torch", columns=["input_ids", "attention_mask"])

train_dataset, test_dataset
# Out:
# (Dataset({
#      features: ['text', 'label', 'input_ids', 'token_type_ids', 'attention_mask', 'special_tokens_mask'],
#      num_rows: 379492
#  }),
#  Dataset({
#      features: ['text', 'label', 'input_ids', 'token_type_ids', 'attention_mask', 'special_tokens_mask'],
#      num_rows: 42166
#  }))

# %% [markdown]
# ### Setup before retraining
#
# Start out with BertForMaskedLM
# - Initialize BERT model with some config set
# - Initialize data collator to mask tokens
# - Set training arguments
# - Intiailize trainer

# %%
# initialize the model with the config
model_config = BertConfig(vocab_size=vocab_size, 
                          max_position_embeddings=max_length)

model = BertForMaskedLM(config=model_config)

# %%
# initialize the data collator, randomly masking 20% (default is 15%) of the 
# tokens for the Masked Language Modeling (MLM) task
data_collator = DataCollatorForLanguageModeling(
    tokenizer=tokenizer, mlm=True, mlm_probability=0.2
)

# %%
# SHS: batch size, CUDA out of memory
#   30: CUDA out of memory. Tried to allocate 1.75 GiB (GPU 0; 24.00 GiB total capacity; 22.44 GiB already allocated
#   25: OutOfMemoryError: CUDA out of memory. Tried to allocate 300.00 MiB (GPU 0; 24.00 GiB total capacity; 22.89 GiB already allocated

training_args = TrainingArguments(
    output_dir=model_dir,           # output dir to where save model checkpoint
    evaluation_strategy="steps",    # evaluate each `logging_steps` steps
    overwrite_output_dir=True,      
    num_train_epochs=10,            # num of training epochs, feel free to tweak
    per_device_train_batch_size=20, # training batch size, depend on GPU memory
    gradient_accumulation_steps=8,  # accumulate gradients before weights update 
    per_device_eval_batch_size=64,  # evaluation batch size
    logging_steps=500,              # evaluate, log and save every 500 steps
    save_steps=500,
    save_safetensors=True,          # save SafeTensors instead of Tensors 
    # load_best_model_at_end=True,  # best in terms of loss
    # save_total_limit=3,           # save 3 model weights to save space
)

# %%
# initialize the trainer and pass everything to it
trainer = Trainer(
    model=model,
    args=training_args,
    data_collator=data_collator,
    train_dataset=train_dataset,
    eval_dataset=test_dataset,
)

# %% [markdown]
# ### Train model

# %%
# train the model
trainer.train()
# Out:
#     <div>
#
#       <progress value='1150' max='23710' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [ 1150/23710 1:33:40 < 30:40:56, 0.20 it/s, Epoch 0.48/10]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>500</td>
#       <td>6.945500</td>
#       <td>6.516377</td>
#     </tr>
#     <tr>
#       <td>1000</td>
#       <td>6.437400</td>
#       <td>6.288446</td>
#     </tr>
#   </tbody>
# </table><p>

# %%
# when you load from pretrained
# model = BertForMaskedLM.from_pretrained(os.path.join(model_dir, "checkpoint-10000"))
# tokenizer = BertTokenizerFast.from_pretrained(model_dir)
fill_mask = pipeline("fill-mask", model=model, tokenizer=tokenizer)

# %%
# perform predictions
example = "It is known that [MASK] is the capital of Germany"
for prediction in fill_mask(example):
  print(prediction)

# %% [markdown]
# ## ___Testing___

# %% [markdown]
# ### Examine the dataset

# %%
dataset.__len__, dataset._format_columns

# %%
diter = dataset.iter(batch_size=5)
dnext = diter.__next__()
type(diter), type(dnext), dnext.keys()

# %%
for key in dnext:
  print(f"{key}: length={len(dnext[key])}, type={type(dnext[key])}")
  for item in dnext[key]:
    if type(item) == str: 
      print(f"  {item[:20]}")
    else:
      print(f"  {item}")

# %% [markdown]
# ### Using custom dataset

# %%
# if you have your custom dataset 
# dataset = LineByLineTextDataset(
#     tokenizer=tokenizer,
#     file_path="path/to/data.txt",
#     block_size=64,
# )

# %%
# or if you have huge custom dataset separated into files
# load the splitted files
# files = ["train1.txt", "train2.txt"] # train3.txt, etc.
# dataset = load_dataset("text", data_files=files, split="train")

# %% [markdown]
# ### Reduce dataset size
#
# Original data:
# - The original has 708241 entries and, after train/test split, these are the training setup:
#   - Num examples = 637,416
#   - Num Epochs = 10
#   - Instantaneous batch size per device = 20
#   - Total train batch size (w. parallel, distributed & accumulation) = 160
#   - Gradient Accumulation steps = 8
#   - Total optimization steps = 39,830
#   - Number of trainable parameters = 109,514,298
# - Killed the process after this amount of progress:
#   - 16/39830 25:58 < 1231:01:01, 0.01 it/s, Epoch 0.00/10
#   - See the calculation below it would take 45 days/epoch (close to the 1231 hrs above but not sure it is per epoch or total).
# - So reduce the dataset set to ~1% of the original (7000), just to see how the training requirement is.
#
# 1% cc_news data
# - Now has 7000 entries
#   - Num examples = 6,300
#   - Num Epochs = 10
#   - Instantaneous batch size per device = 25
#   - Total train batch size (w. parallel, distributed & accumulation) = 200
#   - Gradient Accumulation steps = 8
#   - Total optimization steps = 310
#   - Number of trainable parameters = 109,514,298
# - Killed the process:
#   - 6/310 07:50 < 9:55:52, 0.01 it/s, Epoch 0.16/10
#   - So still need 10 hours!! Man...

# %%
sec_per_epoch = 39830/16*(26*60)
hrs  = sec_per_epoch/60/60
days = hrs/24
sec_per_epoch, hrs, days

# %%
# Load dataset from disk
#https://huggingface.co/docs/datasets/v1.2.1/loading_datasets.html
#https://discuss.huggingface.co/t/load-dataset-from-arrow-file/24999/2

# Process, split/splice dataset
#https://huggingface.co/docs/datasets/v1.4.1/splits.html
#https://huggingface.co/docs/datasets/v1.4.1/processing.html

dataset_small = dataset.select(range(7000))
len(dataset_small)
